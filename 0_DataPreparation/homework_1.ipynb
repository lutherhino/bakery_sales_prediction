# %%
# ─────────────────────────────────────────────
# Zelle 1  |  Imports & Daten laden
# ─────────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

urls = {
    "kiwo"  : "https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/kiwo.csv",
    "umsatz": "https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/umsatzdaten_gekuerzt.csv",
    "wetter": "https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/wetter.csv",
}

kiwo, umsatz, wetter = (pd.read_csv(urls[k]) for k in ("kiwo", "umsatz", "wetter"))

for df in (kiwo, umsatz, wetter):
    df["Datum"] = pd.to_datetime(df["Datum"])

# %%
# ─────────────────────────────────────────────
# Zelle 2  |  Mergen  (umsatz = Master)
# ─────────────────────────────────────────────

# Feiertags-Datensatz laden
feiertage = pd.read_csv('https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/5_Datasets/DE-Feiertage_2020_bis_2035.csv', 
                       sep=';', 
                       encoding='utf-8')

# Datum in feiertage konvertieren (vom deutschen Format DD.MM.YYYY)
feiertage['Datum'] = pd.to_datetime(feiertage['Datum'], format='%d.%m.%Y')

# Binary Flag für Feiertag erstellen
feiertage['ist_feiertag'] = 1

# Feiertage nach Kategorie gruppieren (optional)
def kategorisiere_feiertag(feiertag):
    christliche_feiertage = ['Karfreitag', 'Ostermontag', 'Christi Himmelfahrt', 'Pfingstmontag', 
                            'Fronleichnam', 'Heiligabend', 'Weihnachten', '2. Weihnachtsfeiertag']
    nationale_feiertage = ['Neujahr', 'Tag der Arbeit', 'Tag der Deutschen Einheit']
    
    if any(christ in feiertag for christ in christliche_feiertage):
        return 'christlich'
    elif any(nat in feiertag for nat in nationale_feiertage):
        return 'national'
    else:
        return 'sonstige'

feiertage['feiertag_kategorie'] = feiertage['Feiertag'].apply(kategorisiere_feiertag)

# Hauptmerge wie bisher
df = (
    umsatz
    .merge(kiwo[["Datum", "KielerWoche"]], on="Datum", how="left")  # left statt inner
    .merge(wetter, on="Datum", how="left")
    .merge(feiertage[["Datum", "ist_feiertag", "Feiertag", "feiertag_kategorie"]], 
           on="Datum", how="left")  # Feiertage hinzufügen
)

# Nachbearbeitung
df["KielerWoche"] = df["KielerWoche"].fillna(0).astype(int)
df["ist_feiertag"] = df["ist_feiertag"].fillna(0).astype(int)  # 0 für Nicht-Feiertage
df["feiertag_kategorie"] = df["feiertag_kategorie"].fillna("kein_feiertag")

# Optional: Zusätzliche Features erstellen
# Feiertag am Vortag oder Folgetag (Brückentage)
df = df.sort_values('Datum').reset_index(drop=True)
df['feiertag_vortag'] = df['ist_feiertag'].shift(1).fillna(0).astype(int)
df['feiertag_folgetag'] = df['ist_feiertag'].shift(-1).fillna(0).astype(int)

print("Monatsverteilung:", df["Datum"].dt.month.value_counts().sort_index(), sep="\n")
print("\nFeiertage im Datensatz:", df['ist_feiertag'].sum())
print("Feiertage nach Kategorie:", df['feiertag_kategorie'].value_counts(), sep="\n")

# Beispiel: Zeige einige Feiertage im Datensatz
print("\nBeispiel Feiertage im Datensatz:")
print(df[df['ist_feiertag'] == 1][['Datum', 'Feiertag', 'feiertag_kategorie', 'Umsatz']].head(10))
# Out:
# Monatsverteilung:
# Datum
# 1     756
# 2     705
# 3     759
# 4     731
# 5     736
# 6     745
# 7     904
# 8     756
# 9     747
# 10    777
# 11    886
# 12    832
# Name: count, dtype: int64

# %% [markdown]
# # ─────────────────────────────────────────────
# # Zelle 2  |  Mergen  (umsatz = Master)
# # ─────────────────────────────────────────────
# df = (
#     umsatz
#     .merge(kiwo[["Datum", "KielerWoche"]], on="Datum", how="left")  # left statt inner
#     .merge(wetter, on="Datum", how="left")
#     .merge(feiertage[["Datum", "ist_feiertag", "Feiertag", "feiertag_kategorie"]],
#            on="Datum", how="left")  # Feiertage hinzufügen
#
# )
# df["KielerWoche"] = df["KielerWoche"].fillna(0).astype(int)
#
# print("Monatsverteilung:", df["Datum"].dt.month.value_counts().sort_index(), sep="\n")

# %%
# ─────────────────────────────────────────────
# Zelle 3  |  Erste Reinigung & Winsorisierung
# ─────────────────────────────────────────────
# Duplikate
df = df.drop_duplicates()

# Spaltennamen säubern
df.columns = df.columns.str.strip()

# Winsorisieren von Umsatz
p5, p95 = np.percentile(df["Umsatz"], [5, 95])
df["Umsatz"] = df["Umsatz"].clip(lower=p5, upper=p95)

# %%
# ─────────────────────────────────────────────
# Zelle 4  |  Typkonvertierungen & Feature Engineering
# ─────────────────────────────────────────────
# Warengruppe benennen
mapping = {1:"Brot", 2:"Brötchen", 3:"Croissant", 4:"Konditorei", 5:"Kuchen", 6:"Saisonbrot"}
df["Warengruppe"] = df["Warengruppe"].map(mapping).astype("category")

# Zeitliche Features
df["Wochentag"]  = df["Datum"].dt.day_name().astype("category")
df["Monat"]      = df["Datum"].dt.month.astype("category")
df["Jahr"]       = df["Datum"].dt.year.astype("category")

def season(month):
    return ("Winter","Frühling","Sommer","Herbst")[(month%12)//3]
df["Jahreszeit"] = pd.Categorical(df["Datum"].dt.month.map(season),
                                  categories=["Frühling","Sommer","Herbst","Winter"],
                                  ordered=True)

# Wettercode-Fehlindikator
df["Wettercode_fehlt"] = df["Wettercode"].isna().astype(int)

# %%
# ─────────────────────────────────────────────
# Zelle 5  |  Deskriptive Statistiken & Korrelation
# ─────────────────────────────────────────────
print("DESKRIPTIV:")
display(df.describe(include="all"))

print("\nKORRELATION:")
nums = df.select_dtypes("number")
display(nums.corr())
# Out:
# DESKRIPTIV:
#                   id                          Datum Warengruppe       Umsatz  \
# count   9.334000e+03                           9334        9334  9334.000000
# unique           NaN                            NaN           6          NaN
# top              NaN                            NaN        Brot          NaN
# freq             NaN                            NaN        1819          NaN
# mean    1.559311e+06  2016-01-13 23:56:27.100921344         NaN   201.420387
# min     1.307011e+06            2013-07-01 00:00:00         NaN    59.208548
# 25%     1.410123e+06            2014-10-12 00:00:00         NaN    96.897441
# 50%     1.601102e+06            2016-01-10 00:00:00         NaN   161.900831
# 75%     1.704223e+06            2017-04-22 00:00:00         NaN   280.644663
# max     1.807315e+06            2018-07-31 00:00:00         NaN   494.258576
# std     1.512503e+05                            NaN         NaN   124.753529
#
#         KielerWoche   Bewoelkung   Temperatur  Windgeschwindigkeit  \
# count   9334.000000  9264.000000  9318.000000          9318.000000
# unique          NaN          NaN          NaN                  NaN
# top             NaN          NaN          NaN                  NaN
# freq            NaN          NaN          NaN                  NaN
# mean       0.023891     4.720747    12.028483            10.974780
# min        0.000000     0.000000    -8.475000             3.000000
# 25%        0.000000     3.000000     6.237500             8.000000
# 50%        0.000000     6.000000    11.625000            10.000000
# 75%        0.000000     7.000000    17.962500            13.000000
# max        1.000000     8.000000    31.437500            35.000000
# std        0.152718     2.646273     7.232829             4.131974
#
#          Wettercode Wochentag   Monat    Jahr Jahreszeit  Wettercode_fehlt
# count   7009.000000      9334  9334.0  9334.0       9334       9334.000000
# unique          NaN         7    12.0     6.0          4               NaN
# top             NaN   Tuesday     7.0  2015.0     Herbst               NaN
# freq            NaN      1345   904.0  1848.0       2410               NaN
# mean      36.900128       NaN     NaN     NaN        NaN          0.249089
# min        0.000000       NaN     NaN     NaN        NaN          0.000000
# 25%       10.000000       NaN     NaN     NaN        NaN          0.000000
# 50%       28.000000       NaN     NaN     NaN        NaN          0.000000
# 75%       61.000000       NaN     NaN     NaN        NaN          0.000000
# max       95.000000       NaN     NaN     NaN        NaN          1.000000
# std       27.095884       NaN     NaN     NaN        NaN          0.432509
# KORRELATION:
#                            id    Umsatz  KielerWoche  Bewoelkung  Temperatur  \
# id                   1.000000 -0.079158     0.048994   -0.010526   -0.069656
# Umsatz              -0.079158  1.000000     0.055967   -0.091876    0.224843
# KielerWoche          0.048994  0.055967     1.000000    0.011251    0.138339
# Bewoelkung          -0.010526 -0.091876     0.011251    1.000000   -0.391635
# Temperatur          -0.069656  0.224843     0.138339   -0.391635    1.000000
# Windgeschwindigkeit  0.007566  0.015614     0.020500    0.041809    0.003734
# Wettercode          -0.095554 -0.017002     0.066911    0.525547   -0.086582
# Wettercode_fehlt    -0.188095  0.078565     0.003979   -0.390809    0.313660
#
#                      Windgeschwindigkeit  Wettercode  Wettercode_fehlt
# id                              0.007566   -0.095554         -0.188095
# Umsatz                          0.015614   -0.017002          0.078565
# KielerWoche                     0.020500    0.066911          0.003979
# Bewoelkung                      0.041809    0.525547         -0.390809
# Temperatur                      0.003734   -0.086582          0.313660
# Windgeschwindigkeit             1.000000    0.119232         -0.084334
# Wettercode                      0.119232    1.000000               NaN
# Wettercode_fehlt               -0.084334         NaN          1.000000

# %%
# ─────────────────────────────────────────────
# Zelle 6  |  Plots (überarbeitet)
# ─────────────────────────────────────────────
fig, axes = plt.subplots(3, 2, figsize=(14, 18)); axes = axes.flatten()

sns.histplot(df["Umsatz"], kde=True, bins=30, ax=axes[0])
axes[0].set_title("Umsatzverteilung")

sns.violinplot(x="Jahreszeit", y="Umsatz", data=df,
               order=["Frühling","Sommer","Herbst","Winter"],
               inner="quartile", ax=axes[1])
axes[1].set_title("Umsatz nach Jahreszeit")

sns.barplot(x="Warengruppe", y="Umsatz", data=df,
            order=["Brot","Brötchen","Croissant","Konditorei","Kuchen","Saisonbrot"],
            estimator=np.mean, ci=95, ax=axes[2])
axes[2].set_title("Ø Umsatz nach Warengruppe")

sns.regplot(x="Temperatur", y="Umsatz", data=df,
            scatter_kws={"alpha":0.6}, line_kws={"lw":2}, ax=axes[3])
axes[3].set_title("Umsatz vs. Temperatur (Reg.)")

sns.histplot(data=df, x="Temperatur", y="Umsatz",
             bins=30, cbar=True, cmap="viridis", ax=axes[4])
axes[4].set_title("Umsatz vs. Temperatur (Heatmap)")

sns.barplot(x="Bewoelkung", y="Umsatz", data=df,
            estimator=np.mean, ci=95, ax=axes[5])
axes[5].set_title("Umsatz vs. Bewölkung (95 % CI)")

plt.tight_layout(); plt.show()
# Out:
# /tmp/ipykernel_21575/1812644890.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x="Warengruppe", y="Umsatz", data=df,
# /tmp/ipykernel_21575/1812644890.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x="Bewoelkung", y="Umsatz", data=df,
